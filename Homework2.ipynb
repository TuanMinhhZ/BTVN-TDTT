# %% [markdown]
# <a href="https://colab.research.google.com/github/TuanMinhhZ/BTVN-TDTT/blob/main/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và
# chu vi của nó.

# %%
a=int(input())
b=int(input())
Chcn=(a+b)*2
Shcn =a*b
print(Chcn)
print(Shcn)

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
a=int(input('Bán kính hình tròn:'))
Stron= 3.14*(a**2)
print(f'{Stron:.2f}')

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a,b,c=map(float, input().split())
if a+b>c and a+c>b and b+c>a:
  if a==b==c:
    print("Đây là tam giác đều")
    S= ((a**2)*(3**0.5))/4
    C= 3*a
    print(f"Diện tích tam giác đều:{S:.2f}")
    print(f"Chu vi tam giác đều:{C:.2f}")
  elif a==b or a==c or b==c:
    print("Đây là tam giác cân")
    C= a+b+c
    p=C/2
    S=(p*(p-a)*(p-b)*(p-c))**0.5
    print(f"Diện tích tam giác cân:{S:.2f}")
    print(f"Chu vi tam giác cân:{C:.2f}")
  elif a**2==b**2+c**2 or b**2==a**2+c**2 or c**2==b**2+a**2:
    print("Đây là tam giác vuông")
    C= a+b+c
    p=C/2
    S=(p*(p-a)*(p-b)*(p-c))**0.5
    print(f"Diện tích tam giác vuông:{S:.2f}")
    print(f"Chu vi tam giác vuông:{C:.2f}")
  else:
    print("Đây là tam giác thường")
    C= a+b+c
    p=C/2
    S=(p*(p-a)*(p-b)*(p-c))**0.5
    print(f"Diện tích tam giác thường:{S:.2f}")
    print(f"Chu vi tam giác thường:{C:.2f}")
else:
  print("Đây ko phải là tam giác")

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b=map(float, input().split())
if a==0:
  if b==0:
    print("Phương trinh có vô số nghiệm")
  else:
    print("Phương trình vô nghiệm")
else:
  x=-b/a
  print(f"Phương trình có nghiệm duy nhất:{x}")

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c=map(float, input().split())
if a==0:
  if b==0:
    if c==0:
      print("Phương trinh có vô số nghiệm")
    else:
      print("Phương trình vô nghiệm")
  else:
    x= -c/b
    print(f"Phương trình có nghiệm duy nhất:{x}")
else:
  Delta=b**2-4*a*c
  if Delta<0:
    print("Phương trình vô nghiệm")
  elif Delta==0:
    x=-b/(2*a)
    print(f"Phương trình có nghiệm kép:{x}")
  else:
    x1=(-b+Delta**2)/(2*a)
    x2=(-b-Delta**2)/(2*a)
    print(f"Phương trình có 2 nghiệm phân biệt:{x1}, {x2}")

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d=map(float, input().split())
gia_tri_lon_nhat=a
if b>gia_tri_lon_nhat:
  gia_tri_lon_nhat=b
if c>gia_tri_lon_nhat:
  gia_tri_lon_nhat=c
if d>gia_tri_lon_nhat:
  gia_tri_lon_nhat=d
print(f"Số lớn nhất là:{gia_tri_lon_nhat}")

# %%
a,b,c,d=map(float, input().split())
gia_tri_lon_nhat=max(a,b,c,d)
print(f"Số lớn nhất là:{gia_tri_lon_nhat}")

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d=map(float, input().split())
gia_tri_nho_nhat=a
if b<gia_tri_nho_nhat:
  gia_tri_nho_nhat=b
if c<gia_tri_nho_nhat:
  gia_tri_nho_nhat=c
if d<gia_tri_nho_nhat:
  gia_tri_nho_nhat=d
print(f"Số nhỏ nhất là:{gia_tri_nho_nhat}")

# %%
a,b,c,d=map(float, input().split())
gia_tri_nho_nhat=min(a,b,c,d)
print(f"Số nhỏ nhất là:{gia_tri_nho_nhat}")
