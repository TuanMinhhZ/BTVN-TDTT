# %% [markdown]
# <a href="https://colab.research.google.com/github/TuanMinhhZ/BTVN-TDTT/blob/main/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n=int(input())
m=2*n
print(m)

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a,b,r =map(int, input().split())
stron=(r**2)*3.14
shcn=a*b
s=shcn-stron
print(s)
# Out:
# 1 2 3
# -26.26

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c=input()
if 65<=ord(c)<=90:
  s=ord(c)+32
  print(chr(s))
elif 97<=ord(c)<=122:
  a=ord(c)-32
  print(chr(a))

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c=input()
if ('a' <= c <= 'z') or ('A' <= c <= 'Z'):
        print(f"{c} là kí tự alphabet")
else:
        print(f"{c} không phải là kí tự alphabet")

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input()
if c == 'A':
    print('z')
else:
    ket_qua = chr(ord(c) + 32 - 1)
    print(ket_qua)

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a, b, c = map(int, input().split())
if a+b>c and a+c>b and b+c>a:
  p=(a+b+c)/2
  s= (p*(p-a)*(p-b)*(p-c))**0.5
  print(s)
else:
  print("Khong phai 3 canh cua tam giac")

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
a= input()
if len(a)>=20 and a.islower():
  print(a[4])
  print(a[8])
else:
  print("Error")

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
ten_chu_ho = input("Ten chu ho: ")
chi_so_truoc = int(input("Chi so thang truoc: "))
chi_so_nay = int(input("Chi so thang nay: "))
so_dien = chi_so_nay - chi_so_truoc
tien_dien = 0
if so_dien > 400:
    tien_dien += (so_dien - 400) * 3460
    so_dien = 400
if so_dien > 300:
    tien_dien += (so_dien - 300) * 3350
    so_dien = 300
if so_dien > 200:
    tien_dien += (so_dien - 200) * 2998
    so_dien = 200
if so_dien > 100:
    tien_dien += (so_dien - 100) * 2380
    so_dien = 100
if so_dien > 50:
    tien_dien += (so_dien - 50) * 2050
    so_dien = 50
if so_dien > 0:
    tien_dien += so_dien * 1984
tong_tien = tien_dien * 1.08
tien_phai_tra = int(round(tong_tien))
print(f"Ho va ten: {ten_chu_ho}")
print(f"Tien phai tra la: {tien_phai_tra}")

# %% [markdown]
# Một số bài tập khác

# %% [markdown]
# 1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.

# %%
n=int(input())
if n%2==1:
  print(f"{n} là số lẻ")
else:
  print(f"{n} là số chẵn")

# %%
print("  *  ")
print(" *** ")
print("*****")
# Out:
#   *
#  ***
# *****

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
print(b,a)
# Out:
# Nhập số a: 1
# Nhập số b: 2
# 2 1

# %%
Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị
của phép tính tích giữa \a và \b

# %%
n = int(input("Nhập vào một số nguyên: "))

# Đề bài yêu cầu đếm chữ số trừ dấu (nghĩa là số âm hay dương không quan trọng)
# Ta dùng hàm abs() để lấy giá trị tuyệt đối (biến số âm thành dương)
n_duong = abs(n)
dem = 0

# Xử lý trường hợp đặc biệt nếu người dùng nhập số 0
if n_duong == 0:
    dem = 1
else:
    # Lặp chừng nào số n_duong vẫn còn lớn hơn 0
    while n_duong > 0:
        n_duong = n_duong // 10 # Vứt bỏ chữ số cuối cùng
        dem += 1                # Tăng bộ đếm lên 1

print(f"Số lượng chữ số của số vừa nhập là: {dem}")
# Out:
# Nhập vào một số nguyên: 1234
# Số lượng chữ số của số vừa nhập là: 4

# %%
def tinh_cuoc_taxi(km):

  if km<=0:
    return -1
  if km==1:

# %%
def smart_taxi_fare(car_type, start_hour, km, wait_minutes):
    # --- CÁC THÔNG SỐ GIẢ ĐỊNH (Cần thay đổi theo đề bài thực tế) ---
    GIA_MO_CUA = 15000       # Giá mở cửa
    GIA_MOI_KM = 12000       # Giá cho mỗi km tiếp theo
    PHI_CHO_1_PHUT = 2000    # Phí chờ mỗi phút

    # Tính toán tiền cơ bản
    tong_tien = GIA_MO_CUA + (km * GIA_MOI_KM) + (wait_minutes * PHI_CHO_1_PHUT)

    # Phụ phí ban đêm (Giả sử: Từ 22h đêm đến 5h sáng thu thêm 20%)
    if start_hour >= 22 or start_hour <= 5:
        tong_tien *= 1.20

    # Giảm giá (Giả sử: Đi trên 30km được giảm 10% tổng bill)
    if km > 30:
        tong_tien *= 0.90

    return int(tong_tien)

# Ví dụ chạy thử: Xe loại 1, bắt đầu lúc 23h, đi 35km, chờ 10 phút
# print(smart_taxi_fare(1, 23, 35, 10))
